# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = sns.load_dataset('diamonds')  # dataset available in seaborn
d.head()   # gives first 5 records
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
plt.plot(d.carat)  # univariable plot-1 feature

# %%
d.carat  # is a data
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
plt.plot(d.x, d.y)   # x vs y plot

# %%
d
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
plt.plot(d.x)
plt.plot(d.y)
plt.plot(d.z)

# %%
plt.figure(figsize=(6,4))  # reduce size of plot
plt.plot(d.x,label='x column')
#plt.plot(d.y)
plt.plot(d.z, label='z column')
plt.legend()
plt.title('line plot')  # used to give title
plt.xlabel('index') # label for x axis
plt.ylabel('price') # label for y axis
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(6,4))  # reduce size of plot
plt.plot(d.z, label='z column')
plt.legend()
plt.title('line plot sample')  # used to give title
plt.xlabel('index data') # label for x axis
plt.ylabel('price data') # label for y axis
# Out:
# Text(0, 0.5, 'price data')

# %%
plt.figure(figsize=(6,4))  # reduce size of plot
plt.plot(d.x,label='x column')
#plt.plot(d.y)
plt.legend()
plt.title('line plot')  # used to give title
plt.xlabel('index') # label for x axis
plt.ylabel('price') # label for y axis

plt.figure(figsize=(6,4))  # reduce size of plot
plt.plot(d.z, label='z column')
plt.legend()
plt.title('line plot sample')  # used to give title
plt.xlabel('index data') # label for x axis
plt.ylabel('price data') # label for y axis
# Out:
# Text(0, 0.5, 'price data')

# %%
days= ['monday', 'tuesday', 'wednesday', 'thursday']
count = [12, 34, 56, 33]
plt.plot(days, count)

# %%
days= ['monday', 'tuesday', 'wednesday', 'thursday']
count = [12, 34, 56, 33]
plt.plot(days, count)
plt.title('Days plot')  # used to give title
plt.xlabel('Days') # label for x axis
plt.ylabel('price data') # label for y axis
# Out:
# Text(0, 0.5, 'price data')

# %%
plt.plot(days, count, color='red')

# %%
plt.plot(days, count, color='red', linestyle= '--')

# %%
plt.plot(days, count, color='red', linestyle= '--', marker = '*')

# %%
plt.plot(days, count, color='red', linestyle= '', marker = '*')

# %%
plt.plot?    # gives help

# %%
plt.plot(days, count, 'r-.D')   # shortcut for string data

# %%
# bar plot
plt.bar(days, count)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(days, count, width=0.3) # to give width
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(days, count,width=0.3, alpha=.3)  # lighter shade
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(days, count,width=0.3, alpha=.73, color= ['r','y','b','g']) # different colors for bars
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar?  # help

# %%
#Q. combine two bar plots in one
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

# Make a data definition
days= ['monday', 'tuesday', 'wednesday', 'thursday']
data={ 'count' : [112, 134, 156, 133],
'count1' :[100, 123, 133 ,111 ] }

df =pd.DataFrame(data, columns = ['count', 'count1'], index = ['monday', 'tuesday', 'wednesday', 'thursday'])
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh()     #horizontal bar chart
# Out:
# <Axes: >

# %%
d.cut.unique()    #unique cut values
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
ct = d.cut.value_counts()
ct
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
ct.index   # gives index--x axis
# Out:
# CategoricalIndex(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], categories=['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], ordered=False, dtype='category')

# %%
ct.values # gives values-y axis
# Out:
# array([21551, 13791, 12082,  4906,  1610])

# %%
plt.bar(ct.index, ct.values)
# Out:
# <BarContainer object of 5 artists>

# %%
# bar plot over color and clarity
plt.bar(ct.index, ct.values, width=0.3, alpha=.60, color= ['r','y','b','g'])
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import matplotlib.pyplot as plot

# Make a data definition
a1 = [2.2, 2.7, 3.2, 3.7, 4.2, 4.7]
b1 = [2, 5, 8, 11, 14, 17]

a2 = [4, 10, 14, 20, 24, 32]
b2 = [2.3, 5.5, 11, 18, 8.9, 10.2]

r1 = np.arange(6)
width1 = 0.5

# Create the first subplot
plot.subplot(1, 2, 2)
plot.bar(r1, a1, width=width1)
plot.bar(r1 + width1, b1, width=width1)

# Create the second subplot
plot.subplot(1, 2, 1)
plot.bar(r1, a2, width=width1)
plot.bar(r1 + width1, b2, width=width1)

# Display the plot
plot.show()

# %%
#use of colors
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'guava', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', 'green', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

# %%
#use of labels
import matplotlib.pyplot as plt
import numpy as np

species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence


fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count

    ax.bar_label(p, label_type='center')

ax.set_title('Number of penguins by sex')
ax.legend()

# %%
#grouped bar chart with labels
import matplotlib.pyplot as plt
import numpy as np

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)
# Out:
# (0.0, 250.0)
